# %% [markdown]
# <a href="https://colab.research.google.com/github/Santoshk2006/BVVS1/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
df = pd.read_csv("/content/titanic-1.csv")
df.info()
df.describe()
df.head()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     885 non-null    float64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          713 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         883 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 83.7+ KB
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887       0.0       2                     Montvila, Rev. Juozas
# ...

# %%
print(df.isnull().sum())
df = df.fillna(df.mean(numeric_only=True))
# Out:
# PassengerId      0
# Survived         6
# Pclass           0
# Name             0
# Sex              0
# Age            178
# SibSp            0
# Parch            0
# Ticket           0
# Fare             8
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df['Survived'].isnull().sum())
print(df['Age'].isnull().sum())
# Out:
# 0
# 0

# %%
sns.countplot(x="Pclass",data=df)
plt.show()
